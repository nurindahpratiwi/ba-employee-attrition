# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Import Dataset

# %%
df = pd.read_csv('hr-employee-attrition.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ## Data Description (Characteristics)

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %% [markdown]
# - The average age is 36 years, there are very young people with 18 years (young trainees or interns?) and people with 60 years (managers with many years of work?).
# - There are people who live very close to work, almost next door, and others are almost an hour's drive away!
# - The average is 6500 usd, the lowest  reach 1000 usd (the young trainees?) and the highest almost 20000 usd (that 60 year old boss with many years behind him?).
# - There are employees who have been working for almost 40 years and others who have just started! The average is 7 years.

# %%
attrition_yes = df.loc[df["Attrition"] == "Yes"]
attrition_no = df.loc[df["Attrition"] == "No"]

# %%
df_mean_attrition = pd.concat((attrition_yes.mean(),attrition_no.mean()),axis=1)
df_mean_attrition.columns = ["Yes","No"]
df_mean_attrition.style.background_gradient(cmap="tab20_r",axis=1)
# Out:
# /tmp/ipykernel_577/2001672348.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_mean_attrition = pd.concat((attrition_yes.mean(),attrition_no.mean()),axis=1)
# <style type="text/css">
# #T_fda16_row0_col0, #T_fda16_row1_col0, #T_fda16_row2_col1, #T_fda16_row3_col0, #T_fda16_row4_col0, #T_fda16_row4_col1, #T_fda16_row5_col0, #T_fda16_row6_col0, #T_fda16_row7_col0, #T_fda16_row8_col0, #T_fda16_row9_col0, #T_fda16_row10_col0, #T_fda16_row11_col0, #T_fda16_row12_col1, #T_fda16_row13_col1, #T_fda16_row14_col0, #T_fda16_row15_col1, #T_fda16_row16_col0, #T_fda16_row17_col0, #T_fda16_row17_col1, #T_fda16_row18_col0, #T_fda16_row19_col0, #T_fda16_row20_col0, #T_fda16_row21_col0, #T_fda16_row22_col0, #T_fda16_row23_col0, #T_fda16_row24_col0, #T_fda16_row25_col0 {
#   background-color: #9edae5;
#   color: #000000;
# }
# ...

# %% [markdown]
# ### Characteristic of employee who want to leave
# - Their average age is 33 years
# - The distance from home tends to be further from the office
# - Less satisfactory work environment
# - Their have lower income (make sense because they have been working less years)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Checking null value

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ## Checking unique value

# %%
df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %% [markdown]
# ## Drop some column
# Since Over18, EmployeeCount and StandardHours have only one kind of value, I am removing those columns.

# %%
df.drop(['Over18', 'StandardHours', 'EmployeeCount'], axis = 'columns', inplace = True)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
# 3                 3          4  Life Sciences               5
# 4                 2          1        Medical               7
#
#    EnvironmentSatisfaction  ... PerformanceRating  RelationshipSatisfaction  \
# 0                        2  ...                 3                         1
# ...

# %% [markdown]
# ## Decoded categorical features

# %%
#Details of categorical columns
categorical_col = []
for column in df.columns:
    if df[column].dtype == object and len(df[column].unique()) <= 30:
        print("{}: {}".format(column, df[column].unique()))
        print(df[column].value_counts())
        print("==================================================")
        categorical_col.append(column)
# Out:
# Attrition: ['Yes' 'No']
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# ...
# BusinessTravel: ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# ...
# Department: ['Sales' 'Research & Development' 'Human Resources']
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# ...
# EducationField: ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
# ...
# Gender: ['Female' 'Male']
# Male      882
# Female    588
# Name: Gender, dtype: int64
# ...
# JobRole: ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
# ...

# %%
numerical_col = []
for column in df.columns:
    if df[column].dtype != object:
        # and len(df[column].unique()) <= 30
        print("{}: {}".format(column, df[column].unique()))
        print("==================================================")
        numerical_col.append(column)
# Out:
# Age: [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# ...
# DailyRate: [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
#   489  807  827  871  665 1040 1420  240 1280  534 1456  658  142 1127
#  1031 1189 1354 1467  922  394 1312  750  441  684  249  841  147  528
#   594  470  957  542  802 1355 1150 1329  959 1033 1316  364  438  689
#   201 1427  857  933 1181 1395  662 1436  194  967 1496 1169 1145  630
# ...

# %%
#Unencoding Categorical Features
col = ['EnvironmentSatisfaction','JobInvolvement','JobSatisfaction','RelationshipSatisfaction']

for i in df['Education']:
    df['Education'].replace({1:'Below College',2:'College',3:'Bachelor',4:'Master', 5:'Doctor'},
                       inplace = True)
    
for i in df['PerformanceRating']:
    df['PerformanceRating'].replace({1:'Low', 2:'Good',3:'Excellent',4:'Outstanding'},
                                  inplace = True)
    
for i in df['WorkLifeBalance']:
    df['WorkLifeBalance'].replace({1: 'Bad', 2:'Good', 3:'Better', 4:'Best'}, 
                                  inplace = True)

for i in df[col]:
    df[i].replace({1:'Low', 2:'Medium',3:'High', 4:'Very High'},
                   inplace = True)


decoded = ['EnvironmentSatisfaction','JobInvolvement','JobSatisfaction','RelationshipSatisfaction',
           'Education', 'PerformanceRating', 'WorkLifeBalance']

for i in df[decoded]:
    print(f'======== {i} ========\n')
    print(df[i].value_counts().sort_values(ascending=False))
    print('- - ' * 20)
# Out:
# ======== EnvironmentSatisfaction ========
#
# High         453
# Very High    446
# Medium       287
# Low          284
# Name: EnvironmentSatisfaction, dtype: int64
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# ======== JobInvolvement ========
#
# High         868
# Medium       375
# Very High    144
# Low           83
# Name: JobInvolvement, dtype: int64
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# ======== JobSatisfaction ========
#
# Very High    459
# High         442
# Low          289
# Medium       280
# Name: JobSatisfaction, dtype: int64
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# ======== RelationshipSatisfaction ========
#
# High         459
# Very High    432
# Medium       303
# Low          276
# Name: RelationshipSatisfaction, dtype: int64
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# ======== Education ========
#
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
attrition = df['Attrition'].value_counts()['Yes']
attr = df.loc[df['Attrition'] == 'Yes']
att_rate = (attrition / df.shape[0]) * 100 
print (f"Number of Attrition is: {attrition} employee and average attrition rate is: {att_rate:.2f}")
# Out:
# Number of Attrition is: 237 employee and average attrition rate is: 16.12

# %% [markdown]
# Based on articles [here](https://insightglobal.com/blog/employee-attrition-rate-how-to-calculate-improve/#:~:text=What%20is%20a%20Good%20Attrition,industry%2C%20depending%20on%20the%20circumstances)
#
# Good attrition is round 10%, meanwhile attrition on the dataset is about 16%. So, the average is very high compared to what would be normal

# %% [markdown]
# ## Categorical Variable Analysis

# %%
def cat_plot(i):
    fig = sns.countplot(x = attr[i], palette= 'pastel')
    fig.set(title = f'{i} x Attrition')
    fig.bar_label(fig.containers[0])

# %%
categorical_col = categorical_col + decoded

cat_col =[]

for each in categorical_col:
    if each not in cat_col:
        cat_col.append(each)

for i in cat_col:
    plt.figure(figsize=(15,8))
    #plt.xticks(rotation=60)
    cat_plot(i)

# %% [markdown]
# - Most employees left worked from Research & Development department
# - Most of them being laboratory technicians, sales executives or research scientists.
# - These employees have excellent performance ratings.
# - Most of them had a Bachelor's degree and their education field was mostly either Life Sciences, Medical and Marketing.
# - These employee majoraly presented high job involvement, and high satisfaction with their job, and also a better work life balance, but large amount of them said they've had a low satisfaction with the work environment.

# %% [markdown]
# ## Numerical Variabel Analysis

# %%
num_col = list(set(numerical_col) - set(decoded))

def numeric_plot(i):
    fig = sns.histplot(x = attr[i], palette= 'pastel')
    fig.set(title = f'{i} x Attrition')
    fig.bar_label(fig.containers[0])

# %%
for i in num_col:
    plt.figure(figsize=(15,8))
    numeric_plot(i)

# %% [markdown]
# - As employee grow old, the less they tend to leave
# - Most employee attrition from 25 to 35 years old
# - The more years at company, the more working years, and the more years in current role they less likely to leave company
# - Employees who tend to leave the company are those who are young, less work years and their salary ranges from 2000 - 3000

# %% [markdown]
# # Descriptive Analysis (What Happened?)

# %% [markdown]
# ## Q1. Which gender group has more attrition?

# %%
ax = sns.countplot(data=df, x='Attrition', hue='Gender')

# %% [markdown]
# Males are tend to leave company than females

# %% [markdown]
# ## Q2. Are females get paid less than males?

# %%
sns.histplot(data=df, x='HourlyRate', hue='Gender', bins=12)
# Out:
# <AxesSubplot:xlabel='HourlyRate', ylabel='Count'>

# %% [markdown]
# We can say that there are more males that make a higher hourly rate but we can't say that on average males get paid more or the median pay for a male is greater than a female.

# %%
sns.boxplot(data=df, x='Gender', y='HourlyRate')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='HourlyRate'>

# %% [markdown]
# We can see that actually females have a higher median but not by much.

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(15,8))
sns.boxplot(data=df.loc[df['Attrition']=='Yes'], y='HourlyRate', x='Gender', ax=ax1)
sns.boxplot(data=df.loc[df['Attrition']=='No'], y='HourlyRate', x='Gender', ax=ax2)
plt.show()
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='HourlyRate'>
# <AxesSubplot:xlabel='Gender', ylabel='HourlyRate'>

# %% [markdown]
# - We can see that for when attrition = yes men are paid more, whereas when attrition = no men are paid less.
# - we can see that females who are no longer with the company had a lower median hourly rate than males who left the company.

# %% [markdown]
# ## Q3. Which education levels have higher attrition rate?

# %%
sns.countplot(data=df.loc[df['Attrition']=='Yes'], x='Education')
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %% [markdown]
# The bachelor's group leads by as many as the highest number of educations background

# %%
ax = sns.countplot(data=df, x='Education', hue='Attrition')
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')
# Out:
# Text(0, 9, '44')
# Text(0, 9, '31')
# Text(0, 9, '58')
# Text(0, 9, '99')
# Text(0, 9, '5')
# Text(0, 9, '238')
# Text(0, 9, '139')
# Text(0, 9, '340')
# Text(0, 9, '473')
# Text(0, 9, '43')

# %%
list_edu = ['Bachelor', 'Below College', 'College', 'Doctor', 'Master']
rate_edu_attr =[]
for i in list_edu:
    count_edu = len(df.loc[df['Education']==i])
    count_edu_attr = len(df.loc[(df['Attrition']=='Yes') & (df['Education']==i)])
    calc = count_edu_attr/count_edu * 100
    rate_edu_attr.append(calc)
    print (f"{i} Rate Attrition: {calc:.2f}%")

plt.plot(list_edu, rate_edu_attr)
plt.ylim((0,20))
plt.ylabel("Percentage")
plt.xlabel("Education Level")
plt.show()
# Out:
# Bachelor Rate Attrition: 17.31%
# Below College Rate Attrition: 18.24%
# College Rate Attrition: 15.60%
# Doctor Rate Attrition: 10.42%
# Master Rate Attrition: 14.57%
# (0.0, 20.0)
# Text(0, 0.5, 'Percentage')
# Text(0.5, 0, 'Education Level')

# %% [markdown]
# The results from this graph tell us the people who have an education level below college have a highest attrition rate. This happened might be because they have no degree to help them persue other jobs.

# %% [markdown]
# ## Q4. Are senior roles have more attrition than junior or entry level roles?

# %%
sns.stripplot(data=df, x='JobLevel', y='TotalWorkingYears', hue='Attrition', dodge=True, jitter=True)
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='TotalWorkingYears'>

# %% [markdown]
# - Entry level roles have a higher chance of leaving the company compared to junior roles

# %%
BTravel =['Travel_Rarely', 'Travel_Frequently', 'Non-Travel']
overtime =['Yes', 'No']

for i in BTravel:
    for j in overtime:
        var = df.loc[(df['BusinessTravel'] == i) & (df['OverTime'] == j)]
        ax = sns.barplot(data=var, x='JobLevel', y='TotalWorkingYears', hue='Attrition').set(title=f'BusinessTravel: {i} x Overtime: {j}')
        plt.show()

# %%
sns.catplot(
    data=df, x="JobLevel", y="TotalWorkingYears", col='BusinessTravel', hue='Attrition', dodge=True
)

# %%
sns.catplot(
    data=df, x="JobLevel", y="TotalWorkingYears", col='OverTime', hue='Attrition', dodge=True
)

# %% [markdown]
# ## Q5. Which age values has highest attrition rate?

# %%
df["Attrition_numeric"] = df['Attrition'].copy()

for i in df["Attrition_numeric"]:
    df["Attrition_numeric"].replace({'Yes':1, 'No':0},
                                  inplace = True)

# %%
cut_age = pd.cut(df["Age"],bins=[18,30,50,60],include_lowest=False)
df.groupby(cut_age)["Attrition_numeric"].value_counts(normalize=True).unstack()
# Out:
# Attrition_numeric         0         1
# Age
# (18, 30]           0.746032  0.253968
# (30, 50]           0.873539  0.126461
# (50, 60]           0.874126  0.125874

# %%
# age
plt.figure(figsize=(6,4))
ax = sns.distplot(attrition_yes["Age"],hist=False,label="Yes",color="r")
ax = sns.distplot(attrition_no["Age"],hist=False,label="No",color="#C0EDD2")

plt.ylabel("Density")
plt.legend()
# Get the two lines from the axes to generate shading
l1 = ax.lines[0]
l2 = ax.lines[1]

# Get the xy data from the lines so that we can shade
x1 = l1.get_xydata()[:,0]
y1 = l1.get_xydata()[:,1]
x2 = l2.get_xydata()[:,0]
y2 = l2.get_xydata()[:,1]
ax.fill_between(x1,y1, color="red", alpha=0.3)
ax.fill_between(x2,y2, color="#C0EDD2", alpha=0.3)
sns.despine()
ax.text(5,0.064,"Age Density Distribution by Attrition",
        fontsize=15,        
         fontweight='bold') 
ax.text(5,0.06,"The older you get, the less you want to change jobs?",
        fontsize=12) 
plt.show(block=False)
# Out:
# /home/wiwaaw/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/wiwaaw/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Density')
# Text(5, 0.064, 'Age Density Distribution by Attrition')
# Text(5, 0.06, 'The older you get, the less you want to change jobs?')

# %% [markdown]
# # Diagnostic Analysis (Why did it happened?)

# %% [markdown]
# ## Q1. How the attrition rate is affected by both MonthlyIncome based on JobRole?

# %%
attrition_yes_df = df[df['Attrition']=='Yes']
attrition_no_df = df[df['Attrition']=='No']

# EducationField value counts correlated to Y/N Attrition
department_yes = attrition_yes_df['Department'].value_counts()
department_no = attrition_no_df['Department'].value_counts()

# JobRole value counts correlated to Y/N Attrition
job_role_yes = attrition_yes_df['JobRole'].value_counts()
job_role_no = attrition_no_df['JobRole'].value_counts()

# %%
# Create combo chart
fig, ax1 = plt.subplots(figsize=(30,15))
color = 'tab:purple'

# Bar plot creation
ax1.set_xlabel('JobRole', fontsize=20)
ax1.set_ylabel('MonthlyIncome', fontsize=20, color=color)
ax1 = sns.barplot(x='JobRole', y='MonthlyIncome', data = df, palette='ch:s=.25,rot=-.25')
ax1.tick_params(axis='y')

# Calculate and add Attrition rates
attrition_rate = pd.DataFrame(pd.crosstab(df['JobRole'],df['Attrition']))
attrition_rate.insert(2, 'Attr%', value = (job_role_yes/(job_role_no + job_role_yes) *100))

# Specify that we want to share the same x-axis
ax2 = ax1.twinx()
color = 'tab:red'

# Line plot creation
ax2.set_ylabel('% Attrition', fontsize=20, color=color)
ax2 = sns.lineplot(x='JobRole', y='Attr%', data= attrition_rate, sort=False, color=color)
ax2.tick_params(axis='y', color=color)

plt.show()
# Out:
# Text(0.5, 0, 'JobRole')
# Text(0, 0.5, 'MonthlyIncome')
# Text(0, 0.5, '% Attrition')

# %% [markdown]
# ## Q2. Do the working Department and JobRole impact the attrition rate?

# %%
# Yes/No Attrition
atrrition_yes_df = df[df['Attrition']=='Yes']
atrrition_no_df = df[df['Attrition']=='No']

# EducationField value counts correlated to Y/N Attrition
department_yes = atrrition_yes_df['Department'].value_counts()
department_no = atrrition_no_df['Department'].value_counts()

# JobRole value counts correlated to Y/N Attrition
job_role_yes = atrrition_yes_df['JobRole'].value_counts()
job_role_no = atrrition_no_df['JobRole'].value_counts()

# %%
fig, axes = plt.subplots(1,2, figsize=(20, 6))

# Pie chart with wide wedgeprop for EducationField
axes[0].pie((department_yes*100/department_no), wedgeprops=dict(width=0.6), labels=(department_yes/department_no).index,autopct='%1.1f%%', startangle=180);
axes[0].text(0., 0., '', horizontalalignment='center', verticalalignment='center')
axes[0].axis('equal')

# Pie chart with wide wedgeprop for JobRole
axes[1].pie((job_role_yes*100/job_role_no), wedgeprops=dict(width=0.6), labels=(job_role_yes/job_role_no).index,autopct='%1.1f%%', startangle=180);
axes[1].text(0., 0., '', horizontalalignment='center', verticalalignment='center')
axes[1].axis('equal')

# Display charts
plt.show()
# Out:
# ([<matplotlib.patches.Wedge at 0x7f717280cfd0>,
# ...
#  [Text(-0.790104781592887, -0.7653328910376559, 'Research & Development'),
#   Text(1.0303822854347804, -0.3851134194782092, 'Sales'),
#   Text(-0.4721543164366783, 0.9935141173985467, 'Human Resources')],
#  [Text(-0.4309662445052111, -0.4174543042023577, '24.5%'),
#   Text(0.5620267011462438, -0.21006186516993228, '39.6%'),
#   Text(-0.25753871805636996, 0.5419167913082981, '35.9%')])
# Text(0.0, 0.0, '')
# (-1.100994192414473,
#  1.1208780407039345,
#  -1.1072328497062038,
#  1.1165207373622261)
# ([<matplotlib.patches.Wedge at 0x7f71727a8ac0>,
# ...
#  [Text(-1.0918568560103294, -0.13359867508040235, 'Healthcare Representative'),
#   Text(-0.8133230154834115, -0.7406116880558737, 'Human Resources'),
#   Text(0.19953510320600482, -1.0817512387737622, 'Laboratory Technician'),
#   Text(0.7789911133219927, -0.7766420316757024, 'Manager'),
#   Text(0.9221779080167701, -0.5996564899722289, 'Manufacturing Director'),
# ...

# %% [markdown]
# As displayed above:
# - `Sales`(39.6%) department has the highest attrition rates, follows up by `Human Resources`(35.9%) and `Research & Development`(24.5%)
# - `Sales Representative` has the highest attrition rates (34.7%), following by `Laboratory Technician` (16.5%) and `Human  Resources`(15.8%)
# - `Research Director`(1.3%), `Manufacturing Director` & `Healthcare Representative`(3.9%), `Manager`(2.7%) have the lowest attrition rates

# %% [markdown]
# ## Q3. How does promotion affect the attrition rate?

# %%
yearpromo_count_df=df['YearsSinceLastPromotion'].value_counts()

#Scatter plot creation
sns.scatterplot(x=df.YearsSinceLastPromotion, y=yearpromo_count_df, hue=df.Attrition, s=100)
plt.xlabel("YearsSinceLastPromotion")
plt.ylabel("No of Associates");

# %% [markdown]
# As displayed above:
#
# All of the employees who got promoted within less than 1 year, attrited
# This may illustrate the pattern of the employees stay at the company and wait until their promotion while start looking for opportunities outside

# %% [markdown]
# ## Q4: How does years of working affect the attrition rate?
#
# To answer, a scatter plot will be visualized with `YearsInCurrentRole` and `No of Associates`

# %%
yearincurrentrole_count_df=df['YearsInCurrentRole'].value_counts()

#Scatter plot creation
sns.scatterplot(x=df.YearsInCurrentRole, y=yearincurrentrole_count_df, hue=df.Attrition, s=100)
plt.xlabel("YearsInCurrentRole")
plt.ylabel("No of Associates");

# %% [markdown]
# As displayed above:
#
# Most of the employees with less than 2 years in current role, attrited
# Also, there are a high number of employees with approx 4 years of working, attrited
# This may illustrate the pattern of the employees stay at the company and wait until their promotion while start looking for opportunities outside as mentioned above & the employees with approx 4 years of working tend to attrite based on the desire to change workplace, jobrole or occupancy

# %% [markdown]
# ## Q5: Does the company stocks for employee impact the attrition rate?
#
# We visualize `StockOptionLevel` and `Counts of holder` and the `% Attrition`of StockOptionLevel value_counts to Yes/No answers via a multiple combo chart

# %%
# StockOptionLevel value counts correlated to Y/N Attrition
stock_option_count = df['StockOptionLevel'].value_counts()
stockoption_yes = atrrition_yes_df['StockOptionLevel'].value_counts()
stockoption_no = atrrition_no_df['StockOptionLevel'].value_counts()

# Calculate and add Attrition rates
stock_count = pd.DataFrame(pd.crosstab(df['StockOptionLevel'],df['Attrition']))
stock_count.insert(2, 'Attr%', value = (stockoption_yes/stockoption_no *100))
stock_count.insert(2, 'Counts', value = stock_option_count)

stock_count
# Out:
# Attrition          No  Yes  Counts      Attr%
# StockOptionLevel
# 0                 477  154     631  32.285115
# 1                 540   56     596  10.370370
# 2                 146   12     158   8.219178
# 3                  70   15      85  21.428571

# %%
# Create DataFrame for valid interpretation of 'StockOptionLevel' input
stock_att=df.groupby(['StockOptionLevel','Attrition']).apply(lambda x:x['StockOptionLevel'].count()).reset_index(name='Counts')

stock_att
# Out:
#    StockOptionLevel Attrition  Counts
# 0                 0        No     477
# 1                 0       Yes     154
# 2                 1        No     540
# 3                 1       Yes      56
# 4                 2        No     146
# 5                 2       Yes      12
# 6                 3        No      70
# 7                 3       Yes      15

# %%
# Create combo chart
fig, ax1 = plt.subplots(figsize=(20,10))
color = 'tab:purple'

# Bar plot creation
ax1.set_xlabel('StockOptionLevel', fontsize=20)
ax1.set_ylabel('Counts', fontsize=20, color=color)
ax1 = sns.barplot(x='StockOptionLevel', y='Counts', hue='Attrition',data = stock_att, palette='ch:s=.25,rot=-.25')

# Calculate and add Attrition rates
stock_count = pd.DataFrame(pd.crosstab(df['StockOptionLevel'],df['Attrition']))
stock_count.insert(2, 'Attr%', value = (stockoption_yes/(stockoption_no + stockoption_yes) *100))
stock_count.insert(2, 'Counts', value = stock_option_count)

# Specify that we want to share the same x-axis
ax2 = ax1.twinx()
color = 'tab:red'

# Line plot creation
ax2.set_ylabel('% Attrition', fontsize=20, color=color)
ax2 = sns.lineplot(x='StockOptionLevel', y='Attr%', data=stock_count, sort=False, color=color)
ax2.tick_params(axis='y', color=color)

plt.show()
# Out:
# Text(0.5, 0, 'StockOptionLevel')
# Text(0, 0.5, 'Counts')
# Text(0, 0.5, '% Attrition')

# %% [markdown]
# As displayed above:
#
# - The employees with limited `StockOptionLevel`(0) have higher attrition rates(24.4%)
# - Since the `StockOptionLevel` raises much higher(3), the holder might want to attrite to receive the benefits (21.4%) to move to other jobrole, or company

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome      Education EducationField  EmployeeNumber  \
# 0                 1        College  Life Sciences               1
# 1                 8  Below College  Life Sciences               2
# 2                 2        College          Other               4
# 3                 3         Master  Life Sciences               5
# 4                 2  Below College        Medical               7
#
#   EnvironmentSatisfaction  ... RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
df_decode = df.copy()

# %%
for i in df_decode["Attrition"]:
    df_decode["Attrition"].replace({'Yes':1, 'No':0},
                                  inplace = True)

# %%
col = ['EnvironmentSatisfaction','JobInvolvement','JobSatisfaction','RelationshipSatisfaction']

for i in df_decode['Education']:
    df_decode['Education'].replace({'Below College':1,'College':2,'Bachelor':3,'Master':4, 'Doctor':5},
                       inplace = True)
    
for i in df_decode['PerformanceRating']:
    df_decode['PerformanceRating'].replace({'Low':1, 'Good':2,'Excellent':3,'Outstanding':4},
                                  inplace = True)
    
for i in df_decode['WorkLifeBalance']:
    df_decode['WorkLifeBalance'].replace({'Bad':1, 'Good':2, 'Better':3, 'Best':4}, 
                                  inplace = True)

for i in df_decode[col]:
    df_decode[i].replace({'Low':1, 'Medium':2,'High':3, 'Very High':4},
                   inplace = True)

# %%
matrix = df_decode.corr().round(2)
fig, ax = plt.subplots(figsize=(16, 12))
ax = sns.heatmap(matrix, annot=True, linewidths=.5)
#ax.set_yticklabels([i.strftime("%Y-%m-%d %H:%M:%S") for i in df.index], rotation=0)

# %% [markdown]
# ## Q6. Does the relationship satisfaction and overtime impact the attrition rate?

# %%
# marital status and gender
#colors = ["#C0EDD2","#FF0018"]
plt.figure(figsize=(14,6))
plt.suptitle('OverTime and relationship versus Attritions Percentage',fontweight="bold",fontsize=18,y=1.0)

for i,column in enumerate(["RelationshipSatisfaction","OverTime"],1):
    group =df.groupby(column)["Attrition_numeric"].value_counts(normalize=True).to_frame().unstack()

    plt.subplot(1, 3,i)
    sns.barplot(x=group.index,y=('Attrition_numeric', 0),data=group,color="#C0EDD2",label="Atrition 0")
    sns.barplot(x=group.index,y=('Attrition_numeric', 1),data=group,color="#FF0018",label="Atrition 1")
    if i == 1:
        plt.ylabel("Attrition,s Percentage",fontweight="bold")
    else:
        plt.ylabel("",fontweight="bold")
    plt.xlabel(column,fontweight="bold")
    plt.legend()
    plt.grid(False)
# Out:
# Text(0.5, 1.0, 'OverTime and relationship versus Attritions Percentage')
# <AxesSubplot:>
# <AxesSubplot:xlabel='RelationshipSatisfaction', ylabel="('Attrition_numeric', 0)">
# <AxesSubplot:xlabel='RelationshipSatisfaction', ylabel="('Attrition_numeric', 1)">
# Text(0, 0.5, 'Attrition,s Percentage')
# Text(0.5, 0, 'RelationshipSatisfaction')
# <AxesSubplot:>
# <AxesSubplot:xlabel='OverTime', ylabel="('Attrition_numeric', 0)">
# <AxesSubplot:xlabel='OverTime', ylabel="('Attrition_numeric', 1)">
# Text(0, 0.5, '')
# Text(0.5, 0, 'OverTime')

# %% [markdown]
# - Working a lot of overtime and low satisfaction level are important factors to take into account.
